# %% [markdown]
# # plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def square(x):
    return - x**2 + 1

# %%
a = np.linspace(-5, 5, 200)  # [-5, 5] 之内取 200 个点
plt.plot(a, square(a))
plt.show()
